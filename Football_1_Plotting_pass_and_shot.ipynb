# %% [markdown]
# <a href="https://colab.research.google.com/github/sreyaschaithanya/football_analysis/blob/main/Football_1_Plotting_pass_and_shot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#! git clone https://github.com/statsbomb/open-data.git
from google.colab import drive
drive.mount('/content/drive')
#!rm -rf /content/open-data
#!cp -r "/content/drive/My Drive/Football/open-data" "open-data"
#!cp "/content/drive/My Drive/Football/open-data.zip" "open-data.zip"
#!unzip /content/open-data.zip -d /content/
#from google.colab import files

#files.download('open-data.zip')
# Out:
# Mounted at /content/drive

# %%
DATA_PATH = "/content/drive/My Drive/Football/open-data/data/"
MATCHES_PATH = DATA_PATH+"matches/"

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed Mar 25 17:32:00 2020

@author: davsu428
"""
import matplotlib.pyplot as plt
from matplotlib.patches import Arc

def createPitch(length,width, unity,linecolor): # in meters
    # Code by @JPJ_dejong

    """
    creates a plot in which the 'length' is the length of the pitch (goal to goal).
    And 'width' is the width of the pitch (sideline to sideline). 
    Fill in the unity in meters or in yards.

    """
    #Set unity
    if unity == "meters":
        # Set boundaries
        if length >= 120.5 or width >= 75.5:
            return(str("Field dimensions are too big for meters as unity, didn't you mean yards as unity?\
                       Otherwise the maximum length is 120 meters and the maximum width is 75 meters. Please try again"))
        #Run program if unity and boundaries are accepted
        else:
            #Create figure
            fig=plt.figure()
            #fig.set_size_inches(7, 5)
            ax=fig.add_subplot(1,1,1)
           
            #Pitch Outline & Centre Line
            plt.plot([0,0],[0,width], color=linecolor)
            plt.plot([0,length],[width,width], color=linecolor)
            plt.plot([length,length],[width,0], color=linecolor)
            plt.plot([length,0],[0,0], color=linecolor)
            plt.plot([length/2,length/2],[0,width], color=linecolor)
            
            #Left Penalty Area
            plt.plot([16.5 ,16.5],[(width/2 +16.5),(width/2-16.5)],color=linecolor)
            plt.plot([0,16.5],[(width/2 +16.5),(width/2 +16.5)],color=linecolor)
            plt.plot([16.5,0],[(width/2 -16.5),(width/2 -16.5)],color=linecolor)
            
            #Right Penalty Area
            plt.plot([(length-16.5),length],[(width/2 +16.5),(width/2 +16.5)],color=linecolor)
            plt.plot([(length-16.5), (length-16.5)],[(width/2 +16.5),(width/2-16.5)],color=linecolor)
            plt.plot([(length-16.5),length],[(width/2 -16.5),(width/2 -16.5)],color=linecolor)
            
            #Left 5-meters Box
            plt.plot([0,5.5],[(width/2+7.32/2+5.5),(width/2+7.32/2+5.5)],color=linecolor)
            plt.plot([5.5,5.5],[(width/2+7.32/2+5.5),(width/2-7.32/2-5.5)],color=linecolor)
            plt.plot([5.5,0.5],[(width/2-7.32/2-5.5),(width/2-7.32/2-5.5)],color=linecolor)
            
            #Right 5 -eters Box
            plt.plot([length,length-5.5],[(width/2+7.32/2+5.5),(width/2+7.32/2+5.5)],color=linecolor)
            plt.plot([length-5.5,length-5.5],[(width/2+7.32/2+5.5),width/2-7.32/2-5.5],color=linecolor)
            plt.plot([length-5.5,length],[width/2-7.32/2-5.5,width/2-7.32/2-5.5],color=linecolor)
            
            #Prepare Circles
            centreCircle = plt.Circle((length/2,width/2),9.15,color=linecolor,fill=False)
            centreSpot = plt.Circle((length/2,width/2),0.8,color=linecolor)
            leftPenSpot = plt.Circle((11,width/2),0.8,color=linecolor)
            rightPenSpot = plt.Circle((length-11,width/2),0.8,color=linecolor)
            
            #Draw Circles
            ax.add_patch(centreCircle)
            ax.add_patch(centreSpot)
            ax.add_patch(leftPenSpot)
            ax.add_patch(rightPenSpot)
            
            #Prepare Arcs
            leftArc = Arc((11,width/2),height=18.3,width=18.3,angle=0,theta1=308,theta2=52,color=linecolor)
            rightArc = Arc((length-11,width/2),height=18.3,width=18.3,angle=0,theta1=128,theta2=232,color=linecolor)
            
            #Draw Arcs
            ax.add_patch(leftArc)
            ax.add_patch(rightArc)
            #Axis titles

    #check unity again
    elif unity == "yards":
        #check boundaries again
        if length <= 95:
            return(str("Didn't you mean meters as unity?"))
        elif length >= 131 or width >= 101:
            return(str("Field dimensions are too big. Maximum length is 130, maximum width is 100"))
        #Run program if unity and boundaries are accepted
        else:
            #Create figure
            fig=plt.figure()
            #fig.set_size_inches(7, 5)
            ax=fig.add_subplot(1,1,1)
           
            #Pitch Outline & Centre Line
            plt.plot([0,0],[0,width], color=linecolor)
            plt.plot([0,length],[width,width], color=linecolor)
            plt.plot([length,length],[width,0], color=linecolor)
            plt.plot([length,0],[0,0], color=linecolor)
            plt.plot([length/2,length/2],[0,width], color=linecolor)
            
            #Left Penalty Area
            plt.plot([18 ,18],[(width/2 +18),(width/2-18)],color=linecolor)
            plt.plot([0,18],[(width/2 +18),(width/2 +18)],color=linecolor)
            plt.plot([18,0],[(width/2 -18),(width/2 -18)],color=linecolor)
            
            #Right Penalty Area
            plt.plot([(length-18),length],[(width/2 +18),(width/2 +18)],color=linecolor)
            plt.plot([(length-18), (length-18)],[(width/2 +18),(width/2-18)],color=linecolor)
            plt.plot([(length-18),length],[(width/2 -18),(width/2 -18)],color=linecolor)
            
            #Left 6-yard Box
            plt.plot([0,6],[(width/2+7.32/2+6),(width/2+7.32/2+6)],color=linecolor)
            plt.plot([6,6],[(width/2+7.32/2+6),(width/2-7.32/2-6)],color=linecolor)
            plt.plot([6,0],[(width/2-7.32/2-6),(width/2-7.32/2-6)],color=linecolor)
            
            #Right 6-yard Box
            plt.plot([length,length-6],[(width/2+7.32/2+6),(width/2+7.32/2+6)],color=linecolor)
            plt.plot([length-6,length-6],[(width/2+7.32/2+6),width/2-7.32/2-6],color=linecolor)
            plt.plot([length-6,length],[(width/2-7.32/2-6),width/2-7.32/2-6],color=linecolor)
            
            #Prepare Circles; 10 yards distance. penalty on 12 yards
            centreCircle = plt.Circle((length/2,width/2),10,color=linecolor,fill=False)
            centreSpot = plt.Circle((length/2,width/2),0.8,color=linecolor)
            leftPenSpot = plt.Circle((12,width/2),0.8,color=linecolor)
            rightPenSpot = plt.Circle((length-12,width/2),0.8,color=linecolor)
            
            #Draw Circles
            ax.add_patch(centreCircle)
            ax.add_patch(centreSpot)
            ax.add_patch(leftPenSpot)
            ax.add_patch(rightPenSpot)
            
            #Prepare Arcs
            leftArc = Arc((11,width/2),height=20,width=20,angle=0,theta1=312,theta2=48,color=linecolor)
            rightArc = Arc((length-11,width/2),height=20,width=20,angle=0,theta1=130,theta2=230,color=linecolor)
            
            #Draw Arcs
            ax.add_patch(leftArc)
            ax.add_patch(rightArc)
                
    #Tidy Axes
    plt.axis('off')
    
    return fig,ax


def createPitchOld():
    #Taken from FC Python        
    #Create figure
    fig=plt.figure()
    ax=fig.add_subplot(1,1,1)

    #Pitch Outline & Centre Line
    plt.plot([0,0],[0,90], color=linecolor)
    plt.plot([0,130],[90,90], color=linecolor)
    plt.plot([130,130],[90,0], color=linecolor)
    plt.plot([130,0],[0,0], color=linecolor)
    plt.plot([65,65],[0,90], color=linecolor)
    
    #Left Penalty Area
    plt.plot([16.5,16.5],[65,25],color=linecolor)
    plt.plot([0,16.5],[65,65],color=linecolor)
    plt.plot([16.5,0],[25,25],color=linecolor)
    
    #Right Penalty Area
    plt.plot([130,113.5],[65,65],color=linecolor)
    plt.plot([113.5,113.5],[65,25],color=linecolor)
    plt.plot([113.5,130],[25,25],color=linecolor)
    
    #Left 6-yard Box
    plt.plot([0,5.5],[54,54],color=linecolor)
    plt.plot([5.5,5.5],[54,36],color=linecolor)
    plt.plot([5.5,0.5],[36,36],color=linecolor)
    
    #Right 6-yard Box
    plt.plot([130,124.5],[54,54],color=linecolor)
    plt.plot([124.5,124.5],[54,36],color=linecolor)
    plt.plot([124.5,130],[36,36],color=linecolor)
    
    #Prepare Circles
    centreCircle = plt.Circle((65,45),9.15,color=linecolor,fill=False)
    centreSpot = plt.Circle((65,45),0.8,color=linecolor)
    leftPenSpot = plt.Circle((11,45),0.8,color=linecolor)
    rightPenSpot = plt.Circle((119,45),0.8,color=linecolor)
    
    #Draw Circles
    ax.add_patch(centreCircle)
    ax.add_patch(centreSpot)
    ax.add_patch(leftPenSpot)
    ax.add_patch(rightPenSpot)
    
    #Prepare Arcs
    leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color=linecolor)
    rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color=linecolor)

    #Draw Arcs
    ax.add_patch(leftArc)
    ax.add_patch(rightArc)
    
    #Tidy Axes
    plt.axis('off')
    
    return fig,ax

def createGoalMouth():
    #Adopted from FC Python
    #Create figure
    fig=plt.figure()
    ax=fig.add_subplot(1,1,1)

    linecolor='black'

    #Pitch Outline & Centre Line
    plt.plot([0,65],[0,0], color=linecolor)
    plt.plot([65,65],[50,0], color=linecolor)
    plt.plot([0,0],[50,0], color=linecolor)
    
    #Left Penalty Area
    plt.plot([12.5,52.5],[16.5,16.5],color=linecolor)
    plt.plot([52.5,52.5],[16.5,0],color=linecolor)
    plt.plot([12.5,12.5],[0,16.5],color=linecolor)
    
    #Left 6-yard Box
    plt.plot([41.5,41.5],[5.5,0],color=linecolor)
    plt.plot([23.5,41.5],[5.5,5.5],color=linecolor)
    plt.plot([23.5,23.5],[0,5.5],color=linecolor)
    
    #Goal
    plt.plot([41.5-5.34,41.5-5.34],[-2,0],color=linecolor)
    plt.plot([23.5+5.34,41.5-5.34],[-2,-2],color=linecolor)
    plt.plot([23.5+5.34,23.5+5.34],[0,-2],color=linecolor)
    
    #Prepare Circles
    leftPenSpot = plt.Circle((65/2,11),0.8,color=linecolor)
    
    #Draw Circles
    ax.add_patch(leftPenSpot)
    
    #Prepare Arcs
    leftArc = Arc((32.5,11),height=18.3,width=18.3,angle=0,theta1=38,theta2=142,color=linecolor)
    
    #Draw Arcs
    ax.add_patch(leftArc)
    
    #Tidy Axes
    plt.axis('off')
    
    return fig,ax

# %%
import pandas as pd
import json

# %%
competitions = pd.read_json(DATA_PATH+"competitions.json")

# %%
competitions.head()
# Out:
#    competition_id  season_id  ...               match_updated   match_available
# 0              16          4  ...            2020-07-29T05:00  2020-07-29T05:00
# 1              16          1  ...            2020-07-29T05:00  2020-07-29T05:00
# 2              16          2  ...  2020-08-26T12:33:15.869622  2020-07-29T05:00
# 3              16         27  ...  2020-08-26T12:33:15.869622  2020-07-29T05:00
# 4              16         26  ...  2020-08-26T12:33:15.869622  2020-07-29T05:00
#
# [5 rows x 8 columns]

# %%
competitions.describe()
# Out:
#        competition_id  season_id
# count       37.000000  37.000000
# mean        17.729730  25.675676
# std         13.251098  16.721666
# min          2.000000   1.000000
# 25%         11.000000  21.000000
# 50%         16.000000  25.000000
# 75%         16.000000  39.000000
# max         72.000000  76.000000

# %%
competitions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   competition_id      37 non-null     int64
#  1   season_id           37 non-null     int64
#  2   country_name        37 non-null     object
#  3   competition_name    37 non-null     object
#  4   competition_gender  37 non-null     object
#  5   season_name         37 non-null     object
#  6   match_updated       37 non-null     object
#  7   match_available     37 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 2.4+ KB

# %%
competitions["competition_id"].unique(), competitions["competition_id"].nunique()
# Out:
# (array([16, 37, 43, 11, 49,  2, 72]), 7)

# %%
#show all the competitions and the related files for matches
pd.set_option("display.max_rows", None, "display.max_columns", None)
for i in competitions["competition_id"].unique():
    print(competitions[competitions["competition_id"]==i])
# Out:
#     competition_id  season_id country_name  competition_name  \
# 0               16          4       Europe  Champions League
# 1               16          1       Europe  Champions League
# 2               16          2       Europe  Champions League
# 3               16         27       Europe  Champions League
# 4               16         26       Europe  Champions League
# 5               16         25       Europe  Champions League
# 6               16         24       Europe  Champions League
# 7               16         23       Europe  Champions League
# 8               16         22       Europe  Champions League
# 9               16         21       Europe  Champions League
# 10              16         41       Europe  Champions League
# 11              16         39       Europe  Champions League
# 12              16         37       Europe  Champions League
# 13              16         44       Europe  Champions League
# 14              16         76       Europe  Champions League
#
#    competition_gender season_name               match_updated  \
# 0                male   2018/2019            2020-07-29T05:00
# 1                male   2017/2018            2020-07-29T05:00
# 2                male   2016/2017  2020-08-26T12:33:15.869622
# 3                male   2015/2016  2020-08-26T12:33:15.869622
# 4                male   2014/2015  2020-08-26T12:33:15.869622
# 5                male   2013/2014  2020-08-26T12:33:15.869622
# 22            2020-07-29T05:00
# 23            2020-07-29T05:00
# 24            2020-07-29T05:00
# 25            2020-07-29T05:00
# 26            2020-07-29T05:00
# 27            2020-07-29T05:00
# 28            2020-07-29T05:00
# 29            2020-07-29T05:00
# 30            2020-07-29T05:00
# 31            2020-07-29T05:00
# 32            2020-07-29T05:00
# 33            2020-07-29T05:00
#     competition_id  season_id              country_name competition_name  \
# 34              49          3  United States of America             NWSL
#
#    competition_gender season_name     match_updated   match_available
# 34             female        2018  2020-07-29T05:00  2020-07-29T05:00
#     competition_id  season_id country_name competition_name  \
# 35               2         44      England   Premier League
#
#    competition_gender season_name               match_updated  \
# 35               male   2003/2004  2020-08-31T20:40:28.969635
#
#                match_available
# 35  2020-08-31T20:40:28.969635
#     competition_id  season_id   country_name   competition_name  \
# 36              72         30  International  Women's World Cup
#
#    competition_gender season_name     match_updated   match_available
# 36             female        2019  2020-07-29T05:00  2020-07-29T05:00

# %%
# show files
import glob
competitions_path_list = glob.glob(MATCHES_PATH+"/*")
competition_file_dict = {}
for i in competitions_path_list:
    competition_file_dict[i] = glob.glob(i+"/*.json")
competition_file_dict
# Out:
# {'/content/drive/My Drive/Football/open-data/data/matches/11': ['/content/drive/My Drive/Football/open-data/data/matches/11/4.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/11/21.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/11/22.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/11/38.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/11/25.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/11/41.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/11/39.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/11/26.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/11/42.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/11/1.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/11/40.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/11/24.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/11/2.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/11/37.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/11/23.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/11/27.json'],
#  '/content/drive/My Drive/Football/open-data/data/matches/16': ['/content/drive/My Drive/Football/open-data/data/matches/16/4.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/16/22.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/16/25.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/16/27.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/16/76.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/16/26.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/16/1.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/16/21.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/16/23.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/16/42.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/16/37.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/16/24.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/16/39.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/16/44.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/16/2.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/16/41.json'],
#  '/content/drive/My Drive/Football/open-data/data/matches/2': ['/content/drive/My Drive/Football/open-data/data/matches/2/44.json'],
#  '/content/drive/My Drive/Football/open-data/data/matches/37': ['/content/drive/My Drive/Football/open-data/data/matches/37/4.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/37/42.json',
#   '/content/drive/My Drive/Football/open-data/data/matches/37/90.json'],
#  '/content/drive/My Drive/Football/open-data/data/matches/43': ['/content/drive/My Drive/Football/open-data/data/matches/43/3.json'],
#  '/content/drive/My Drive/Football/open-data/data/matches/49': ['/content/drive/My Drive/Football/open-data/data/matches/49/3.json'],
#  '/content/drive/My Drive/Football/open-data/data/matches/72': ['/content/drive/My Drive/Football/open-data/data/matches/72/30.json']}

# %%
DATA_PATH
# Out:
# '/content/drive/My Drive/Football/open-data/data/'

# %%
with open(DATA_PATH + 'matches/72/30.json') as f:
    matches = json.load(f)

# %%
matches[0]
# Out:
# {'away_score': 0,
#  'away_team': {'away_team_gender': 'female',
#   'away_team_group': None,
#   'away_team_id': 1206,
#   'away_team_name': "Canada Women's",
#   'country': {'id': 40, 'name': 'Canada'},
#   'managers': [{'country': {'id': 61, 'name': 'Denmark'},
#     'dob': '1971-01-17',
#     'id': 172,
#     'name': 'Kenneth Heiner-Møller',
#     'nickname': None}]},
#  'competition': {'competition_id': 72,
#   'competition_name': "Women's World Cup",
#   'country_name': 'International'},
#  'competition_stage': {'id': 33, 'name': 'Round of 16'},
#  'home_score': 1,
#  'home_team': {'country': {'id': 220, 'name': 'Sweden'},
#   'home_team_gender': 'female',
#   'home_team_group': None,
#   'home_team_id': 858,
#   'home_team_name': "Sweden Women's",
#   'managers': [{'country': {'id': 220, 'name': 'Sweden'},
#     'dob': None,
#     'id': 3016,
#     'name': 'Peter Gerhardsson',
#     'nickname': None}]},
#  'kick_off': '21:00:00.000',
#  'last_updated': '2020-07-29T05:00',
#  'match_date': '2019-06-24',
#  'match_id': 69163,
#  'match_status': 'available',
#  'match_week': 4,
#  'metadata': {'data_version': '1.1.0',
#   'shot_fidelity_version': '2',
#   'xy_fidelity_version': '2'},
#  'referee': {'id': 1640, 'name': 'K. Jacewicz'},
#  'season': {'season_id': 30, 'season_name': '2019'},
#  'stadium': {'country': {'id': 78, 'name': 'France'},
#   'id': 154,
#   'name': 'Parc des Princes'}}

# %%
for match in matches:
    if match["home_team"]['home_team_name']=="Sweden Women's" or match["away_team"]['away_team_name']=="Sweden Women's":
        print("match between: "+ match["home_team"]['home_team_name']+" vs " +match["away_team"]['away_team_name'] +" with score {}:{}".format(match["home_score"],match["away_score"]))
# Out:
# match between: Sweden Women's vs Canada Women's with score 1:0
# match between: England Women's vs Sweden Women's with score 1:2
# match between: Germany Women's vs Sweden Women's with score 1:2
# match between: Sweden Women's vs Thailand Women's with score 5:1
# match between: Chile Women's vs Sweden Women's with score 0:2
# match between: Sweden Women's vs United States Women's with score 0:2
# match between: Netherlands Women's vs Sweden Women's with score 1:0

# %% [markdown]
# # Pitch map

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
pitchLenX = 120
pitchWidY = 80

# %%
match_id = 69301
def get_match(match_id):
    for i in matches:
        if i["match_id"]==match_id:
            return i
def get_event(match_id):
    with open(DATA_PATH+"events/"+str(match_id)+".json") as f:
        event = json.load(f)
    return event
match = get_match(match_id)
events = get_event(match_id)

# %%
match
# Out:
# {'away_score': 2,
#  'away_team': {'away_team_gender': 'female',
#   'away_team_group': None,
#   'away_team_id': 858,
#   'away_team_name': "Sweden Women's",
#   'country': {'id': 220, 'name': 'Sweden'},
#   'managers': [{'country': {'id': 220, 'name': 'Sweden'},
#     'dob': None,
#     'id': 3016,
#     'name': 'Peter Gerhardsson',
#     'nickname': None}]},
#  'competition': {'competition_id': 72,
#   'competition_name': "Women's World Cup",
#   'country_name': 'International'},
#  'competition_stage': {'id': 25, 'name': '3rd Place Final'},
#  'home_score': 1,
#  'home_team': {'country': {'id': 68, 'name': 'England'},
#   'home_team_gender': 'female',
#   'home_team_group': None,
#   'home_team_id': 865,
#   'home_team_name': "England Women's",
#   'managers': [{'country': {'id': 68, 'name': 'England'},
#     'dob': None,
#     'id': 3464,
#     'name': 'Phil Neville',
#     'nickname': None}]},
#  'kick_off': '17:00:00.000',
#  'last_updated': '2020-07-29T05:00',
#  'match_date': '2019-07-06',
#  'match_id': 69301,
#  'match_status': 'available',
#  'match_week': 7,
#  'metadata': {'data_version': '1.1.0',
#   'shot_fidelity_version': '2',
#   'xy_fidelity_version': '2'},
#  'referee': {'id': 745, 'name': 'A. Pustovoitova'},
#  'season': {'season_id': 30, 'season_name': '2019'},
#  'stadium': {'country': {'id': 78, 'name': 'France'},
#   'id': 162,
#   'name': 'Allianz Riviera'}}

# %%
events_df = pd.json_normalize(events)

# %%
events_df.columns.values
# Out:
# array(['id', 'index', 'period', 'timestamp', 'minute', 'second',
#        'possession', 'duration', 'type.id', 'type.name',
#        'possession_team.id', 'possession_team.name', 'play_pattern.id',
#        'play_pattern.name', 'team.id', 'team.name', 'tactics.formation',
#        'tactics.lineup', 'related_events', 'location', 'player.id',
#        'player.name', 'position.id', 'position.name', 'pass.recipient.id',
#        'pass.recipient.name', 'pass.length', 'pass.angle',
#        'pass.height.id', 'pass.height.name', 'pass.end_location',
#        'pass.type.id', 'pass.type.name', 'pass.body_part.id',
#        'pass.body_part.name', 'under_pressure', 'carry.end_location',
#        'pass.outcome.id', 'pass.outcome.name', 'ball_receipt.outcome.id',
#        'ball_receipt.outcome.name', 'out', 'clearance.left_foot',
#        'clearance.body_part.id', 'clearance.body_part.name',
#        'duel.outcome.id', 'duel.outcome.name', 'duel.type.id',
#        'duel.type.name', 'counterpress', 'pass.deflected',
#        'dribble.outcome.id', 'dribble.outcome.name', 'pass.switch',
#        'interception.outcome.id', 'interception.outcome.name',
#        'pass.inswinging', 'pass.technique.id', 'pass.technique.name',
#        'clearance.head', 'pass.cross', 'goalkeeper.outcome.id',
#        'goalkeeper.outcome.name', 'goalkeeper.type.id',
#        'goalkeeper.type.name', 'off_camera', 'clearance.other',
#        'clearance.right_foot', 'shot.statsbomb_xg', 'shot.end_location',
#        'shot.first_time', 'shot.outcome.id', 'shot.outcome.name',
#        'shot.type.id', 'shot.type.name', 'shot.body_part.id',
#        'shot.body_part.name', 'shot.technique.id', 'shot.technique.name',
#        'shot.freeze_frame', 'goalkeeper.technique.id',
#        'goalkeeper.technique.name', 'goalkeeper.body_part.id',
#        'goalkeeper.body_part.name', 'goalkeeper.position.id',
#        'goalkeeper.position.name', 'ball_recovery.recovery_failure',
#        'pass.assisted_shot_id', 'pass.shot_assist', 'pass.through_ball',
#        'shot.key_pass_id', 'shot.saved_to_post',
#        'goalkeeper.shot_saved_to_post', 'foul_won.defensive',
#        'clearance.aerial_won', 'pass.goal_assist',
#        'substitution.outcome.id', 'substitution.outcome.name',
#        'substitution.replacement.id', 'substitution.replacement.name',
#        'miscontrol.aerial_won', 'pass.aerial_won',
#        'foul_committed.type.id', 'foul_committed.type.name',
#        'foul_committed.offensive', 'shot.one_on_one',
#        'goalkeeper.end_location', 'dribble.overrun', 'block.deflection',
#        'pass.cut_back', 'bad_behaviour.card.id',
#        'bad_behaviour.card.name', 'pass.no_touch', 'pass.straight',
#        'block.save_block', 'foul_committed.advantage',
#        'foul_won.advantage', 'foul_committed.card.id',
#        'foul_committed.card.name'], dtype=object)

# %%
shots = events_df[events_df["type.name"]=="Shot"]
shots[["period","minute","location","team.name","shot.outcome.name"]]
# Out:
#       period  minute       location        team.name shot.outcome.name
# 339        1      10  [104.7, 45.5]   Sweden Women's              Goal
# 530        1      15  [110.9, 53.1]   Sweden Women's     Saved to Post
# 719        1      21  [107.8, 26.1]   Sweden Women's              Goal
# 741        1      22   [93.7, 51.1]  England Women's             Saved
# 955        1      30  [108.0, 52.7]  England Women's              Goal
# 1326       1      43   [83.6, 47.1]   Sweden Women's             Saved
# 1484       1      48  [105.4, 25.5]   Sweden Women's             Off T
# 1576       1      50  [108.4, 53.3]  England Women's             Saved
# 1782       2      49   [84.3, 31.3]  England Women's           Blocked
# 1794       2      49   [81.9, 35.2]  England Women's             Off T
# 2011       2      56   [88.6, 39.9]  England Women's           Blocked
# 2204       2      61  [117.5, 48.2]  England Women's             Off T
# 2261       2      63   [63.1, 79.4]  England Women's           Wayward
# 2325       2      65   [95.7, 39.3]   Sweden Women's             Saved
# 2961       2      82   [82.9, 38.3]  England Women's             Off T
# 3093       2      87  [102.9, 51.5]   Sweden Women's             Saved
# 3119       2      89  [107.0, 37.7]  England Women's           Blocked
# 3168       2      90   [89.3, 33.5]  England Women's             Saved
# 3196       2      90  [109.0, 33.4]   Sweden Women's             Saved

# %%
(fig,ax) = createPitch(pitchLenX,pitchWidY,"yards","grey")

# %%
for i,shot in shots.iterrows():
    x = shot.location[0]
    y = shot.location[1]

    goal = shot["shot.outcome.name"] == "Goal"
    shot_team = shot["team.name"]

    circle_size = np.sqrt(shot["shot.statsbomb_xg"]*15)
    print(circle_size)

    if shot_team == "Sweden Women's":
        if goal:
            shotCircle = plt.Circle((x,pitchWidY-y),circle_size,color="red")
            #plt.text(x,pitchWidY-y,"hi") 
        else:
            shotCircle = plt.Circle((x,pitchWidY-y),circle_size,color="red")
            shotCircle.set_alpha(0.2)
    else:
        if goal:
            shotCircle = plt.Circle((pitchLenX-x,y),circle_size,color="blue")
            #plt.text((pitchLenX-x+1),y+1,shot['player.name']) 
        else:
            shotCircle = plt.Circle((pitchLenX-x,y),circle_size,color="blue")
            shotCircle.set_alpha(0.2)
    ax.add_patch(shotCircle)
    #"England Women's"
#plt.show()
# Out:
# 1.3154804445524837
# 0.8414811049572058
# 0.6491755771746192
# 0.453465877988631
# 1.3482839092713375
# 0.39473485404762526
# 2.0316760322452985
# 1.723552871251706
# 0.456252380815706
# 0.36295789011950136
# 0.47181022668017697
# 1.1621432097637536
# 0.7438810792055408
# 0.716430694484819
# 0.35235837580508855
# 0.8354685810968597
# 1.3415841009791374
# 0.36648144564220436
# 2.0386098204413714

# %%
fig

# %% [markdown]
# # passes plotting

# %%
#passes = events_df[(events_df["type.name"]=="Pass") & (events_df["player.name"]=="Sara Caroline Seger") & (events_df["play_pattern.name"]=="Regular Play")]
passes = events_df[(events_df["type.name"]=="Pass") & (events_df["player.name"]=="Sara Caroline Seger")]
# shots[["period","minute","location","team.name","shot.outcome.name"]]
#
#events_df["type.name"].unique()

# %%
#passes[["location"]+[i for i in passes.columns.values if "pass" in i]]
passes
# Out:
# 477       [88.7, 73.0]           NaN            NaN               40.0
# 546        [91.0, 8.7]          66.0       Recovery               38.0
# 570       [64.8, 35.4]           NaN            NaN               38.0
# 583        [86.6, 6.6]           NaN            NaN               40.0
# 660        [52.2, 4.3]           NaN            NaN               40.0
# 1502      [39.0, 69.0]           NaN            NaN               40.0
# 1511      [24.4, 72.3]           NaN            NaN               38.0
# 1589      [91.7, 22.7]           NaN            NaN               40.0
# 1739      [61.9, 20.7]           NaN            NaN               37.0
# 1876      [71.0, 44.7]          66.0       Recovery               40.0
# 1904     [114.2, 78.4]           NaN            NaN               38.0
# 1921      [40.2, 29.8]          66.0       Recovery               38.0
# 1937      [46.5, 22.5]           NaN            NaN               38.0
# 1944      [71.0, 25.2]           NaN            NaN               40.0
# 1959      [53.9, 36.4]           NaN            NaN               40.0
# 2066      [77.2, 67.9]           NaN            NaN               40.0
# 2115       [42.0, 4.2]           NaN            NaN               40.0
# 2127      [66.4, 40.4]           NaN            NaN               40.0
# 2375      [32.5, 76.8]           NaN            NaN               40.0
# 2443       [50.8, 3.4]           NaN            NaN               40.0
# 2479      [30.5, 26.9]          66.0       Recovery               37.0
# 2600      [49.7, 64.9]           NaN            NaN               40.0
# 2644      [76.8, 68.2]          66.0       Recovery               40.0
# 2682      [89.2, 75.0]           NaN            NaN               40.0
# 2696      [73.9, 56.3]           NaN            NaN               40.0
# 2768      [46.8, 18.0]           NaN            NaN                NaN
#
#      pass.body_part.name under_pressure carry.end_location  pass.outcome.id  \
# 213           Right Foot            NaN                NaN              9.0
# 328           Right Foot            NaN                NaN              NaN
# 435           Right Foot           True                NaN              NaN
# 464                 Head            NaN                NaN              9.0
# 477           Right Foot            NaN                NaN              NaN
# 546            Left Foot            NaN                NaN              NaN
# 570            Left Foot            NaN                NaN              NaN
# 583           Right Foot            NaN                NaN              NaN
# 660           Right Foot            NaN                NaN              NaN
# 1502          Right Foot            NaN                NaN              NaN
# 1511           Left Foot            NaN                NaN              NaN
# 1589          Right Foot            NaN                NaN              9.0
# 1739                Head            NaN                NaN              NaN
# 1876          Right Foot            NaN                NaN              NaN
# 1904           Left Foot            NaN                NaN             75.0
# 1921           Left Foot            NaN                NaN              NaN
# 1937           Left Foot            NaN                NaN              9.0
# 1944          Right Foot            NaN                NaN              NaN
# 1959          Right Foot            NaN                NaN              9.0
# 2066          Right Foot            NaN                NaN              9.0
# 2115          Right Foot            NaN                NaN              NaN
# 2127          Right Foot            NaN                NaN              NaN
# 2375          Right Foot           True                NaN              NaN
# 2443          Right Foot            NaN                NaN              NaN
# 2479                Head            NaN                NaN              9.0
# 2600          Right Foot            NaN                NaN              NaN
# 2644          Right Foot            NaN                NaN              9.0
# 2682          Right Foot            NaN                NaN              NaN
# 2696          Right Foot            NaN                NaN              NaN
# 2768                 NaN           True                NaN              9.0
#
#      pass.outcome.name  ball_receipt.outcome.id ball_receipt.outcome.name  \
# 213         Incomplete                      NaN                       NaN
# 328                NaN                      NaN                       NaN
# 2127                      NaN              NaN               NaN
# 2375                      NaN              NaN               NaN
# 2443                      NaN              NaN               NaN
# 2479                      NaN              NaN               NaN
# 2600                      NaN              NaN               NaN
# 2644                      NaN              NaN               NaN
# 2682                      NaN              NaN               NaN
# 2696                      NaN              NaN               NaN
# 2768                      NaN              NaN               NaN
#
#       duel.type.id duel.type.name counterpress pass.deflected  \
# 213            NaN            NaN          NaN            NaN
# 328            NaN            NaN          NaN            NaN
# 435            NaN            NaN          NaN            NaN
# 464            NaN            NaN          NaN            NaN
# 477            NaN            NaN          NaN            NaN
# 546            NaN            NaN          NaN            NaN
# 570            NaN            NaN          NaN            NaN
# 583            NaN            NaN          NaN            NaN
# 660            NaN            NaN          NaN            NaN
# 1502           NaN            NaN          NaN            NaN
# 1511           NaN            NaN          NaN            NaN
# 1589           NaN            NaN          NaN            NaN
# 1739           NaN            NaN          NaN            NaN
# 1876           NaN            NaN          NaN            NaN
# 1904           NaN            NaN          NaN            NaN
# 1921           NaN            NaN          NaN            NaN
# 1937           NaN            NaN          NaN            NaN
# 1944           NaN            NaN          NaN            NaN
# 1959           NaN            NaN          NaN            NaN
# 2066           NaN            NaN          NaN            NaN
# 2115           NaN            NaN          NaN            NaN
# 2127           NaN            NaN          NaN            NaN
# 2375           NaN            NaN          NaN            NaN
# 2443           NaN            NaN          NaN            NaN
# 2479           NaN            NaN          NaN            NaN
# 2600           NaN            NaN          NaN            NaN
# 2644           NaN            NaN          NaN            NaN
# 2682           NaN            NaN          NaN            NaN
# 2696           NaN            NaN          NaN            NaN
# 2768           NaN            NaN          NaN            NaN
#
#       dribble.outcome.id dribble.outcome.name pass.switch  \
# 213                  NaN                  NaN         NaN
# 328                  NaN                  NaN         NaN
# 435                  NaN                  NaN         NaN
# 464                  NaN                  NaN         NaN
# 477                  NaN                  NaN         NaN
# 546                  NaN                  NaN         NaN
# 570                  NaN                  NaN         NaN
# 583                  NaN                  NaN         NaN
# 660                  NaN                  NaN         NaN
# 1502                 NaN                  NaN         NaN
# 1511                 NaN                  NaN         NaN
# 1589                 NaN                  NaN         NaN
# 1739                 NaN                  NaN         NaN
# 1876                 NaN                  NaN         NaN
# 1904                 NaN                  NaN         NaN
# 1921                 NaN                  NaN         NaN
# 1937                 NaN                  NaN         NaN
# 1944                 NaN                  NaN         NaN
# 1959                 NaN                  NaN         NaN
# 2066                 NaN                  NaN         NaN
# 2115                 NaN                  NaN         NaN
# 2127                 NaN                  NaN         NaN
# 2375                 NaN                  NaN         NaN
# 2443                 NaN                  NaN         NaN
# 2479                 NaN                  NaN         NaN
# 2600                 NaN                  NaN         NaN
# 2644                 NaN                  NaN         NaN
# 2682                 NaN                  NaN         NaN
# 2696                 NaN                  NaN         NaN
# 2768                 NaN                  NaN         NaN
#
#       interception.outcome.id interception.outcome.name pass.inswinging  \
# 213                       NaN                       NaN             NaN
# 328                       NaN                       NaN             NaN
# 435                       NaN                       NaN             NaN
# 464                       NaN                       NaN             NaN
# 1511           NaN              NaN                      NaN
# 1589           NaN              NaN                      NaN
# 1739           NaN              NaN                      NaN
# 1876           NaN              NaN                      NaN
# 1904           NaN              NaN                      NaN
# 1921           NaN              NaN                      NaN
# 1937           NaN              NaN                      NaN
# 1944           NaN              NaN                      NaN
# 1959           NaN              NaN                      NaN
# 2066           NaN              NaN                      NaN
# 2115           NaN              NaN                      NaN
# 2127           NaN              NaN                      NaN
# 2375           NaN              NaN                      NaN
# 2443           NaN              NaN                      NaN
# 2479           NaN              NaN                      NaN
# 2600           NaN              NaN                      NaN
# 2644           NaN              NaN                      NaN
# 2682           NaN              NaN                      NaN
# 2696           NaN              NaN                      NaN
# 2768           NaN              NaN                      NaN
#
#      foul_won.advantage  foul_committed.card.id foul_committed.card.name
# 213                 NaN                     NaN                      NaN
# 328                 NaN                     NaN                      NaN
# 435                 NaN                     NaN                      NaN
# 464                 NaN                     NaN                      NaN
# 477                 NaN                     NaN                      NaN
# 546                 NaN                     NaN                      NaN
# 570                 NaN                     NaN                      NaN
# 583                 NaN                     NaN                      NaN
# 660                 NaN                     NaN                      NaN
# 1502                NaN                     NaN                      NaN
# 1511                NaN                     NaN                      NaN
# 1589                NaN                     NaN                      NaN
# 1739                NaN                     NaN                      NaN
# 1876                NaN                     NaN                      NaN
# 1904                NaN                     NaN                      NaN
# 1921                NaN                     NaN                      NaN
# 1937                NaN                     NaN                      NaN
# 1944                NaN                     NaN                      NaN
# 1959                NaN                     NaN                      NaN
# 2066                NaN                     NaN                      NaN
# 2115                NaN                     NaN                      NaN
# 2127                NaN                     NaN                      NaN
# 2375                NaN                     NaN                      NaN
# 2443                NaN                     NaN                      NaN
# 2479                NaN                     NaN                      NaN
# 2600                NaN                     NaN                      NaN
# 2644                NaN                     NaN                      NaN
# 2682                NaN                     NaN                      NaN
# 2696                NaN                     NaN                      NaN
# 2768                NaN                     NaN                      NaN

# %%
(fig,ax) = createPitch(pitchLenX,pitchWidY,"yards","green")
fig.set_size_inches(15, 10.5)
for i,shot in passes.iterrows():
    x_start = shot.location[0]
    y_start = shot.location[1]
    x_end = shot["pass.end_location"][0]
    y_end = shot["pass.end_location"][1]
    #goal = shot["shot.outcome.name"] == "Goal"

    #circle_size = np.sqrt(shot["shot.statsbomb_xg"]*15)
    #print(circle_size)
    shotarrow = plt.Arrow(x_start, pitchWidY-y_start, x_end-x_start, pitchWidY-y_end-pitchWidY+y_start,width=2,color="blue")
    ax.add_patch(shotarrow)
    #"England Women's"
#plt.show()

# %%
(fig, ax) = createPitch(120, 80, 'yards', 'gray')

for i, p in passes.iterrows():    
    x, y = p.location
    x, y = (x,pitchWidY-y)

    end_x, end_y = p["pass.end_location"]
    end_x, end_y = (end_x, pitchWidY-end_y)

    start_circle = plt.Circle((x, y), 1, alpha=.2, color="blue")
    pass_arrow = plt.Arrow(x, y, end_x - x, end_y - y, width=2, color="blue")
    ax.add_patch(pass_arrow)
    ax.add_patch(start_circle)

fig.set_size_inches(15, 10.5)
plt.show()
